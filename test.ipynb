# %%
import cv2
import numpy as np
from roboflow import Roboflow
rf = Roboflow(api_key="Q8frMzPenSHk9xY3093F")
project = rf.workspace("flugunfallerkennung").project("fire-and-smoke-detection-zpsha")
#dataset = project.version(1).download("yolov5")
model = project.version(1).model

rf = Roboflow(api_key="8uqjCkrutuuqGtbdGSus")
project1 = rf.workspace("zinedine-zam").project("initiation")
model1 = project1.version(1).model




# infer on a local image

 #visualize your prediction
#model.predict("your_image.jpg", confidence=40, overlap=30).save("prediction.jpg")

# infer on an image hosted elsewhere
# print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())
import glob
import requests
import base64
from base64 import decodebytes
import io
from PIL import Image
import time
import cv2
from io import BytesIO


parts = []
parts1 = []
url_base = 'https://detect.roboflow.com/'
endpoint = 'fire-and-smoke-detection-zpsha'
endpoint1 = 'initiation'
access_token = '?access_token=Q8frMzPenSHk9xY3093F'
access_token1 = '?access_token=8uqjCkrutuuqGtbdGSus'
format = '&format=json'
confidence = '&confidence=10'
stroke='&stroke=5'
parts.append(url_base)
parts.append(endpoint)
parts.append(access_token)
parts.append(format)
parts.append(confidence)
parts.append(stroke)
url = ''.join(parts)
parts1.append(url_base)
parts1.append(endpoint1)
parts1.append(access_token1)
parts1.append(format)
parts1.append(confidence)
parts1.append(stroke)
url1 = ''.join(parts)

G=0

import mediapipe as mp


mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_pose = mp.solutions.pose


cap=cv2.VideoCapture('pluie.mp4')

frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
   
size = (frame_width, frame_height)
   
# Below VideoWriter object will create
# a frame of above defined The output 
# is stored in 'filename.avi' file.
result = cv2.VideoWriter('detection1.avi', 
                         cv2.VideoWriter_fourcc(*'MJPG'),
                         30, size)
while True:


    ret,image=cap.read()
    print(model.predict(image, confidence=40, overlap=30).json())
    predictions=model.predict(image, confidence=40, overlap=30).json()
    predictions1=model1.predict(image, confidence=40, overlap=30).json()
    print(model1.predict(image, confidence=40, overlap=30).json())

    detections = predictions['predictions']
    detections1 = predictions1['predictions']

    for box in detections:
        x11 =int( box['x'] - box['width'] / 2)
        x21 =int( box['x'] + box['width'] / 2)
        y11 = int(box['y'] - box['height'] / 2)
        y21 = int (box['y'] + box['height'] / 2)
        cv2.rectangle(image,(x11,y11),(x21,y21),(255,0,0),2)
        cv2.putText(image, 'FIRE', (x21, y21), cv2.FONT_HERSHEY_TRIPLEX, 1, (255,255,255), 2)

    
    A=predictions1['predictions']
    if A!=[]:
     B=A[0]
     C=B['class']
    else:
     C=1

    if (C=='chute'):
        
     for box in detections1:
        
        x111 =int( box['x'] - box['width'] / 2)
        x211 =int( box['x'] + box['width'] / 2)
        y111 = int(box['y'] - box['height'] / 2)
        y211 = int (box['y'] + box['height'] / 2)
        cv2.rectangle(image,(x111,y111),(x211,y211),(255,0,0),5)
        cv2.putText(image, 'FALL', (x211, y211), cv2.FONT_HERSHEY_TRIPLEX, 1, (255,255,255), 2)


    with mp_pose.Pose(
        min_detection_confidence=0.2,
        min_tracking_confidence=0.2) as pose:
    
        
        

        # To improve performance, optionally mark the image as not writeable to
        # pass by reference.
        image.flags.writeable = False
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        h,w,z = image.shape
        lm = results.pose_landmarks

        if results.pose_landmarks:
            x1 = int(results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].x * w)
            y1 = int(results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER].y * h)

            x2 = int(results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER].x * w)
            y2 = int(results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER].y * h)

            x3 = int(results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].x * w)
            y3 = int(results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].y * h)

            x4 = int(results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].x * w)
            y4 = int(results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].y * h)
            
            
            if y4 < y2:
                j=j+1
                if j>5:
                 #print("FALL")
                 cv2.putText(image, 'FALL', (x2, y2), cv2.FONT_HERSHEY_TRIPLEX, 1, (255,255,255), 2)
                 cv2.rectangle(image,(x2,y2),(x4,y4),(255,0,0),4)
                 G=1
                else:
                    cv2.rectangle(image,(x2,y2),(x4,y4),(0,255,255),2)

            else:
                G=0
                j = 0 
                cv2.rectangle(image,(x2,y2),(x4,y4),(0,255,255),2)

        # Draw the pose annotation on the image.
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        '''mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style())'''
        # Flip the image horizontally for a selfie-view display.
        cv2.imshow('video',image)
        result.write(image)
        if cv2.waitKey(4) & 0xFF==ord("q"):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 789.5, 'y': 848.0, 'width': 483.0, 'height': 450.0, 'confidence': 0.7085240483283997, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[ 79,  93, 107],
#         [ 83,  97, 111],
#         [ 84,  98, 112],
#         ...,
#         [106, 108, 110],
#         [106, 108, 110],
#         [106, 108, 110]],
#
#        [[ 65,  79,  93],
#         [ 69,  83,  97],
#         [ 68,  82,  96],
#         ...,
#         [106, 108, 110],
#         [106, 108, 110],
#         [106, 108, 110]],
#
#        [[ 62,  76,  90],
#         [ 63,  77,  91],
#         [ 57,  71,  85],
#         ...,
#         [106, 108, 110],
#         [106, 108, 110],
#         [106, 108, 110]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 782.0, 'y': 830.0, 'width': 500.0, 'height': 484.0, 'confidence': 0.7813776135444641, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[ 74,  88, 102],
#         [ 71,  85,  99],
#         [ 72,  86, 100],
#         ...,
#         [119, 115, 118],
#         [119, 115, 118],
#         [119, 115, 118]],
#
#        [[ 99, 113, 127],
#         [ 99, 113, 127],
#         [101, 115, 129],
#         ...,
#         [119, 115, 118],
#         [119, 115, 118],
#         [119, 115, 118]],
#
#        [[115, 129, 143],
#         [116, 130, 144],
#         [118, 132, 146],
#         ...,
#         [119, 115, 118],
#         [119, 115, 118],
#         [119, 115, 118]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 767.0, 'y': 825.5, 'width': 470.0, 'height': 497.0, 'confidence': 0.7539486885070801, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[123, 134, 149],
#         [123, 134, 149],
#         [125, 136, 151],
#         ...,
#         [124, 123, 140],
#         [124, 123, 140],
#         [124, 123, 140]],
#
#        [[122, 133, 148],
#         [122, 133, 148],
#         [124, 135, 150],
#         ...,
#         [123, 123, 135],
#         [123, 123, 135],
#         [123, 123, 135]],
#
#        [[118, 129, 144],
#         [118, 129, 144],
#         [117, 128, 143],
#         ...,
#         [123, 123, 135],
#         [123, 123, 135],
#         [123, 123, 135]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 749.0, 'y': 827.5, 'width': 444.0, 'height': 501.0, 'confidence': 0.7040520310401917, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[114, 125, 140],
#         [115, 126, 141],
#         [115, 126, 141],
#         ...,
#         [122, 112, 148],
#         [121, 111, 147],
#         [121, 111, 147]],
#
#        [[110, 121, 136],
#         [109, 120, 135],
#         [110, 121, 136],
#         ...,
#         [121, 115, 139],
#         [120, 114, 138],
#         [120, 114, 138]],
#
#        [[106, 117, 132],
#         [106, 117, 132],
#         [106, 117, 132],
#         ...,
#         [120, 114, 138],
#         [120, 114, 138],
#         [119, 113, 137]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 740.5, 'y': 832.0, 'width': 379.0, 'height': 494.0, 'confidence': 0.7929562926292419, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[104, 115, 130],
#         [106, 117, 132],
#         [104, 115, 130],
#         ...,
#         [121, 127, 122],
#         [121, 127, 122],
#         [121, 127, 122]],
#
#        [[ 97, 108, 123],
#         [ 96, 107, 122],
#         [ 96, 107, 122],
#         ...,
#         [121, 127, 122],
#         [121, 127, 122],
#         [121, 127, 122]],
#
#        [[ 93, 104, 119],
#         [ 93, 104, 119],
#         [ 93, 104, 119],
#         ...,
#         [121, 127, 122],
#         [121, 127, 122],
#         [121, 127, 122]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 737.5, 'y': 836.0, 'width': 325.0, 'height': 478.0, 'confidence': 0.8571856617927551, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[ 85,  96, 111],
#         [ 86,  97, 112],
#         [ 86,  97, 112],
#         ...,
#         [ 67,  47, 128],
#         [ 67,  48, 126],
#         [ 67,  48, 126]],
#
#        [[ 89, 100, 115],
#         [ 90, 101, 116],
#         [ 90, 101, 116],
#         ...,
#         [ 67,  47, 128],
#         [ 67,  48, 126],
#         [ 67,  48, 126]],
#
#        [[ 96, 107, 122],
#         [ 96, 107, 122],
#         [ 97, 108, 123],
#         ...,
#         [ 67,  47, 128],
#         [ 67,  48, 126],
#         [ 67,  48, 126]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 740.5, 'y': 837.0, 'width': 351.0, 'height': 480.0, 'confidence': 0.8699866533279419, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[ 87,  98, 113],
#         [ 88,  99, 114],
#         [ 89, 100, 115],
#         ...,
#         [ 73,  66, 113],
#         [ 76,  71, 113],
#         [ 78,  73, 115]],
#
#        [[107, 118, 133],
#         [108, 119, 134],
#         [109, 120, 135],
#         ...,
#         [ 72,  62, 112],
#         [ 74,  65, 112],
#         [ 75,  66, 113]],
#
#        [[113, 124, 139],
#         [113, 124, 139],
#         [114, 125, 140],
#         ...,
#         [ 68,  58, 108],
#         [ 71,  62, 109],
#         [ 72,  63, 110]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 761.0, 'y': 834.0, 'width': 396.0, 'height': 492.0, 'confidence': 0.7955819368362427, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[ 93, 104, 119],
#         [ 93, 104, 119],
#         [ 94, 105, 120],
#         ...,
#         [ 98, 104, 120],
#         [ 96, 102, 118],
#         [ 94, 100, 116]],
#
#        [[ 93, 104, 119],
#         [ 94, 105, 120],
#         [ 94, 105, 120],
#         ...,
#         [ 97, 103, 119],
#         [ 94, 100, 116],
#         [ 93,  99, 115]],
#
#        [[ 93, 104, 119],
#         [ 93, 104, 119],
#         [ 94, 105, 120],
#         ...,
#         [ 97, 103, 119],
#         [ 94, 100, 116],
#         [ 92,  98, 114]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 781.0, 'y': 836.5, 'width': 450.0, 'height': 487.0, 'confidence': 0.8056368827819824, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[ 97, 108, 123],
#         [100, 111, 126],
#         [102, 113, 128],
#         ...,
#         [107, 114, 125],
#         [107, 114, 125],
#         [107, 114, 125]],
#
#        [[ 92, 103, 118],
#         [ 96, 107, 122],
#         [101, 112, 127],
#         ...,
#         [ 94, 101, 112],
#         [ 94, 101, 112],
#         [ 94, 101, 112]],
#
#        [[ 92, 103, 118],
#         [ 97, 108, 123],
#         [101, 112, 127],
#         ...,
#         [ 87,  94, 105],
#         [ 87,  94, 105],
#         [ 87,  94, 105]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 784.5, 'y': 836.5, 'width': 479.0, 'height': 483.0, 'confidence': 0.7584453821182251, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[109, 120, 135],
#         [109, 120, 135],
#         [110, 121, 136],
#         ...,
#         [ 96, 103, 114],
#         [ 96, 103, 114],
#         [ 96, 103, 114]],
#
#        [[101, 112, 127],
#         [101, 112, 127],
#         [101, 112, 127],
#         ...,
#         [ 94,  99, 110],
#         [ 94,  99, 110],
#         [ 94,  99, 110]],
#
#        [[ 96, 107, 122],
#         [ 96, 107, 122],
#         [ 97, 108, 123],
#         ...,
#         [ 93,  98, 109],
#         [ 93,  98, 109],
#         [ 92,  97, 108]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 741.5, 'y': 845.5, 'width': 419.0, 'height': 459.0, 'confidence': 0.7835592031478882, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[117, 128, 143],
#         [109, 120, 135],
#         [108, 119, 134],
#         ...,
#         [113, 118, 129],
#         [113, 118, 129],
#         [113, 118, 129]],
#
#        [[115, 127, 139],
#         [111, 123, 135],
#         [111, 123, 135],
#         ...,
#         [112, 119, 130],
#         [113, 120, 131],
#         [114, 121, 132]],
#
#        [[113, 125, 137],
#         [114, 126, 138],
#         [114, 126, 138],
#         ...,
#         [113, 120, 131],
#         [114, 121, 132],
#         [117, 124, 135]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 786.5, 'y': 845.5, 'width': 507.0, 'height': 461.0, 'confidence': 0.4244424104690552, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[103, 114, 129],
#         [103, 114, 129],
#         [104, 115, 130],
#         ...,
#         [ 92,  99, 110],
#         [ 90,  97, 108],
#         [ 87,  94, 105]],
#
#        [[106, 117, 132],
#         [103, 114, 129],
#         [101, 112, 127],
#         ...,
#         [ 90,  97, 108],
#         [ 85,  92, 103],
#         [ 80,  87,  98]],
#
#        [[103, 114, 129],
#         [101, 112, 127],
#         [100, 111, 126],
#         ...,
#         [ 89,  96, 107],
#         [ 82,  89, 100],
#         [ 76,  83,  94]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 660.5, 'y': 857.5, 'width': 283.0, 'height': 445.0, 'confidence': 0.5813300013542175, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [222, 219, 220],
#         [222, 219, 220],
#         [222, 219, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [225, 222, 223],
#         [225, 222, 223],
#         [225, 222, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [244, 241, 242],
#         [244, 241, 242],
#         [244, 241, 242]],
#
#        ...,
#
#        [[115, 126, 141],
#         [115, 126, 141],
#         [115, 126, 141],
#         ...,
#         [112, 117, 128],
#         [112, 117, 128],
#         [113, 118, 129]],
#
#        [[109, 120, 135],
#         [109, 120, 135],
#         [108, 119, 134],
#         ...,
#         [112, 119, 130],
#         [112, 119, 130],
#         [113, 120, 131]],
#
#        [[106, 117, 132],
#         [106, 117, 132],
#         [104, 115, 130],
#         ...,
#         [114, 121, 132],
#         [115, 122, 133],
#         [115, 122, 133]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 664.0, 'y': 858.0, 'width': 286.0, 'height': 438.0, 'confidence': 0.759192943572998, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[116, 127, 142],
#         [116, 127, 142],
#         [116, 127, 142],
#         ...,
#         [ 93,  98, 109],
#         [ 93,  98, 109],
#         [ 93,  98, 109]],
#
#        [[116, 127, 142],
#         [116, 127, 142],
#         [116, 127, 142],
#         ...,
#         [ 93,  98, 109],
#         [ 93,  98, 109],
#         [ 93,  98, 109]],
#
#        [[113, 124, 139],
#         [113, 124, 139],
#         [113, 124, 139],
#         ...,
#         [ 94,  99, 110],
#         [ 94,  99, 110],
#         [ 94,  99, 110]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 897.0, 'y': 814.0, 'width': 258.0, 'height': 504.0, 'confidence': 0.44977331161499023, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[116, 127, 142],
#         [116, 127, 142],
#         [116, 127, 142],
#         ...,
#         [ 93,  98, 109],
#         [ 93,  98, 109],
#         [ 93,  98, 109]],
#
#        [[116, 127, 142],
#         [116, 127, 142],
#         [116, 127, 142],
#         ...,
#         [ 93,  98, 109],
#         [ 93,  98, 109],
#         [ 93,  98, 109]],
#
#        [[113, 124, 139],
#         [113, 124, 139],
#         [113, 124, 139],
#         ...,
#         [ 94,  99, 110],
#         [ 94,  99, 110],
#         [ 94,  99, 110]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 657.0, 'y': 860.5, 'width': 294.0, 'height': 435.0, 'confidence': 0.7485061883926392, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[ 81,  92, 107],
#         [ 81,  92, 107],
#         [ 83,  94, 109],
#         ...,
#         [105, 114, 120],
#         [104, 113, 119],
#         [104, 113, 119]],
#
#        [[ 81,  92, 107],
#         [ 75,  86, 101],
#         [ 78,  89, 104],
#         ...,
#         [104, 113, 119],
#         [103, 112, 118],
#         [103, 112, 118]],
#
#        [[ 80,  91, 106],
#         [ 63,  74,  89],
#         [ 66,  77,  92],
#         ...,
#         [103, 112, 118],
#         [103, 112, 118],
#         [103, 112, 118]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 660.5, 'y': 859.5, 'width': 303.0, 'height': 441.0, 'confidence': 0.6700960397720337, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[117, 128, 143],
#         [116, 127, 142],
#         [113, 124, 139],
#         ...,
#         [116, 121, 132],
#         [115, 120, 131],
#         [115, 120, 131]],
#
#        [[129, 140, 155],
#         [127, 138, 153],
#         [122, 133, 148],
#         ...,
#         [114, 119, 130],
#         [113, 118, 129],
#         [113, 118, 129]],
#
#        [[132, 143, 158],
#         [130, 141, 156],
#         [125, 136, 151],
#         ...,
#         [112, 117, 128],
#         [112, 117, 128],
#         [110, 115, 126]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 936.0, 'y': 819.5, 'width': 252.0, 'height': 483.0, 'confidence': 0.4747740924358368, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[117, 128, 143],
#         [116, 127, 142],
#         [113, 124, 139],
#         ...,
#         [116, 121, 132],
#         [115, 120, 131],
#         [115, 120, 131]],
#
#        [[129, 140, 155],
#         [127, 138, 153],
#         [122, 133, 148],
#         ...,
#         [114, 119, 130],
#         [113, 118, 129],
#         [113, 118, 129]],
#
#        [[132, 143, 158],
#         [130, 141, 156],
#         [125, 136, 151],
#         ...,
#         [112, 117, 128],
#         [112, 117, 128],
#         [110, 115, 126]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 933.5, 'y': 827.5, 'width': 283.0, 'height': 491.0, 'confidence': 0.6113603115081787, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[111, 122, 137],
#         [114, 125, 140],
#         [117, 128, 143],
#         ...,
#         [118, 125, 136],
#         [117, 124, 135],
#         [115, 122, 133]],
#
#        [[111, 122, 137],
#         [111, 122, 137],
#         [111, 122, 137],
#         ...,
#         [113, 120, 131],
#         [112, 119, 130],
#         [112, 119, 130]],
#
#        [[113, 124, 139],
#         [110, 121, 136],
#         [108, 119, 134],
#         ...,
#         [110, 117, 128],
#         [110, 117, 128],
#         [110, 117, 128]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 654.5, 'y': 860.5, 'width': 309.0, 'height': 439.0, 'confidence': 0.5895659327507019, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[111, 122, 137],
#         [114, 125, 140],
#         [117, 128, 143],
#         ...,
#         [118, 125, 136],
#         [117, 124, 135],
#         [115, 122, 133]],
#
#        [[111, 122, 137],
#         [111, 122, 137],
#         [111, 122, 137],
#         ...,
#         [113, 120, 131],
#         [112, 119, 130],
#         [112, 119, 130]],
#
#        [[113, 124, 139],
#         [110, 121, 136],
#         [108, 119, 134],
#         ...,
#         [110, 117, 128],
#         [110, 117, 128],
#         [110, 117, 128]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 637.5, 'y': 858.0, 'width': 311.0, 'height': 444.0, 'confidence': 0.6446103453636169, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[113, 124, 139],
#         [111, 122, 137],
#         [104, 115, 130],
#         ...,
#         [126, 136, 146],
#         [127, 137, 147],
#         [127, 137, 147]],
#
#        [[116, 127, 142],
#         [113, 124, 139],
#         [107, 118, 133],
#         ...,
#         [116, 126, 136],
#         [117, 127, 137],
#         [117, 127, 137]],
#
#        [[117, 128, 143],
#         [115, 126, 141],
#         [110, 121, 136],
#         ...,
#         [113, 123, 133],
#         [113, 123, 133],
#         [113, 123, 133]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 943.5, 'y': 826.0, 'width': 273.0, 'height': 486.0, 'confidence': 0.46959105134010315, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[113, 124, 139],
#         [111, 122, 137],
#         [104, 115, 130],
#         ...,
#         [126, 136, 146],
#         [127, 137, 147],
#         [127, 137, 147]],
#
#        [[116, 127, 142],
#         [113, 124, 139],
#         [107, 118, 133],
#         ...,
#         [116, 126, 136],
#         [117, 127, 137],
#         [117, 127, 137]],
#
#        [[117, 128, 143],
#         [115, 126, 141],
#         [110, 121, 136],
#         ...,
#         [113, 123, 133],
#         [113, 123, 133],
#         [113, 123, 133]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 635.5, 'y': 858.0, 'width': 339.0, 'height': 438.0, 'confidence': 0.6634775400161743, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[109, 120, 135],
#         [110, 121, 136],
#         [110, 121, 136],
#         ...,
#         [113, 122, 137],
#         [116, 125, 140],
#         [117, 126, 141]],
#
#        [[116, 127, 142],
#         [116, 127, 142],
#         [116, 127, 142],
#         ...,
#         [122, 131, 146],
#         [123, 132, 147],
#         [124, 133, 148]],
#
#        [[118, 129, 144],
#         [118, 129, 144],
#         [117, 128, 143],
#         ...,
#         [127, 136, 151],
#         [129, 138, 153],
#         [129, 138, 153]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 976.5, 'y': 821.5, 'width': 207.0, 'height': 487.0, 'confidence': 0.5455845594406128, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[109, 120, 135],
#         [110, 121, 136],
#         [110, 121, 136],
#         ...,
#         [113, 122, 137],
#         [116, 125, 140],
#         [117, 126, 141]],
#
#        [[116, 127, 142],
#         [116, 127, 142],
#         [116, 127, 142],
#         ...,
#         [122, 131, 146],
#         [123, 132, 147],
#         [124, 133, 148]],
#
#        [[118, 129, 144],
#         [118, 129, 144],
#         [117, 128, 143],
#         ...,
#         [127, 136, 151],
#         [129, 138, 153],
#         [129, 138, 153]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 992.5, 'y': 817.0, 'width': 175.0, 'height': 502.0, 'confidence': 0.6055328845977783, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[106, 118, 130],
#         [106, 118, 130],
#         [106, 118, 130],
#         ...,
#         [100, 111, 126],
#         [101, 112, 127],
#         [102, 113, 128]],
#
#        [[107, 119, 131],
#         [109, 121, 133],
#         [111, 123, 135],
#         ...,
#         [ 85,  96, 111],
#         [ 88,  99, 114],
#         [ 90, 101, 116]],
#
#        [[109, 121, 133],
#         [111, 123, 135],
#         [116, 128, 140],
#         ...,
#         [ 81,  92, 107],
#         [ 87,  98, 113],
#         [ 88,  99, 114]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 624.5, 'y': 862.0, 'width': 345.0, 'height': 436.0, 'confidence': 0.5473010540008545, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[106, 118, 130],
#         [106, 118, 130],
#         [106, 118, 130],
#         ...,
#         [100, 111, 126],
#         [101, 112, 127],
#         [102, 113, 128]],
#
#        [[107, 119, 131],
#         [109, 121, 133],
#         [111, 123, 135],
#         ...,
#         [ 85,  96, 111],
#         [ 88,  99, 114],
#         [ 90, 101, 116]],
#
#        [[109, 121, 133],
#         [111, 123, 135],
#         [116, 128, 140],
#         ...,
#         [ 81,  92, 107],
#         [ 87,  98, 113],
#         [ 88,  99, 114]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 666.5, 'y': 863.5, 'width': 427.0, 'height': 433.0, 'confidence': 0.5048626065254211, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[ 95, 107, 119],
#         [ 94, 106, 118],
#         [ 92, 104, 116],
#         ...,
#         [ 90, 101, 116],
#         [ 89, 100, 115],
#         [ 89, 100, 115]],
#
#        [[ 99, 111, 123],
#         [ 96, 108, 120],
#         [ 92, 104, 116],
#         ...,
#         [ 70,  81,  96],
#         [ 68,  79,  94],
#         [ 67,  78,  93]],
#
#        [[108, 120, 132],
#         [106, 118, 130],
#         [100, 112, 124],
#         ...,
#         [ 53,  64,  79],
#         [ 52,  63,  78],
#         [ 52,  63,  78]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 679.0, 'y': 864.5, 'width': 434.0, 'height': 431.0, 'confidence': 0.6341861486434937, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[ 97, 109, 119],
#         [ 89, 101, 111],
#         [ 90, 102, 114],
#         ...,
#         [ 90, 102, 114],
#         [ 89, 101, 113],
#         [ 89, 101, 113]],
#
#        [[ 90, 102, 112],
#         [ 82,  94, 104],
#         [ 83,  95, 107],
#         ...,
#         [ 87,  99, 111],
#         [ 86,  98, 110],
#         [ 86,  98, 110]],
#
#        [[ 83,  95, 105],
#         [ 79,  91, 101],
#         [ 81,  93, 105],
#         ...,
#         [ 85,  97, 109],
#         [ 83,  95, 107],
#         [ 83,  95, 107]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 681.0, 'y': 863.0, 'width': 424.0, 'height': 434.0, 'confidence': 0.6182801723480225, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[ 97, 109, 119],
#         [ 99, 111, 121],
#         [103, 115, 125],
#         ...,
#         [ 98, 112, 126],
#         [ 98, 112, 126],
#         [ 99, 113, 127]],
#
#        [[101, 113, 123],
#         [104, 116, 126],
#         [111, 123, 133],
#         ...,
#         [ 98, 112, 126],
#         [ 98, 112, 126],
#         [ 99, 113, 127]],
#
#        [[104, 116, 126],
#         [108, 120, 130],
#         [115, 127, 137],
#         ...,
#         [ 97, 111, 125],
#         [ 97, 111, 125],
#         [ 98, 112, 126]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 685.0, 'y': 858.5, 'width': 404.0, 'height': 443.0, 'confidence': 0.6775550842285156, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[123, 135, 145],
#         [117, 129, 139],
#         [111, 123, 133],
#         ...,
#         [111, 125, 139],
#         [111, 125, 139],
#         [112, 126, 140]],
#
#        [[128, 140, 150],
#         [121, 133, 143],
#         [115, 127, 137],
#         ...,
#         [107, 121, 135],
#         [107, 121, 135],
#         [109, 123, 137]],
#
#        [[130, 142, 152],
#         [124, 136, 146],
#         [118, 130, 140],
#         ...,
#         [102, 116, 130],
#         [105, 119, 133],
#         [107, 121, 135]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 686.5, 'y': 858.5, 'width': 397.0, 'height': 443.0, 'confidence': 0.6243590712547302, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[ 99, 111, 121],
#         [100, 112, 122],
#         [102, 114, 124],
#         ...,
#         [115, 128, 144],
#         [106, 119, 135],
#         [102, 115, 131]],
#
#        [[106, 118, 128],
#         [107, 119, 129],
#         [109, 121, 131],
#         ...,
#         [115, 128, 144],
#         [102, 115, 131],
#         [ 98, 111, 127]],
#
#        [[115, 127, 137],
#         [116, 128, 138],
#         [118, 130, 140],
#         ...,
#         [115, 128, 144],
#         [101, 114, 130],
#         [ 94, 107, 123]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 691.5, 'y': 857.5, 'width': 395.0, 'height': 445.0, 'confidence': 0.5957410931587219, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[ 96, 108, 118],
#         [ 94, 106, 116],
#         [ 93, 105, 117],
#         ...,
#         [ 83,  96, 112],
#         [ 86,  99, 115],
#         [ 90, 103, 119]],
#
#        [[ 90, 102, 112],
#         [ 89, 101, 111],
#         [ 89, 101, 113],
#         ...,
#         [101, 114, 130],
#         [105, 118, 134],
#         [108, 121, 137]],
#
#        [[ 92, 104, 114],
#         [ 90, 102, 112],
#         [ 89, 101, 113],
#         ...,
#         [114, 127, 143],
#         [119, 132, 148],
#         [122, 135, 151]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 699.5, 'y': 882.5, 'width': 413.0, 'height': 395.0, 'confidence': 0.5692711472511292, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[117, 129, 139],
#         [110, 122, 132],
#         [102, 114, 124],
#         ...,
#         [ 59,  72,  88],
#         [ 59,  71,  90],
#         [ 59,  71,  90]],
#
#        [[117, 129, 139],
#         [109, 121, 131],
#         [ 96, 108, 118],
#         ...,
#         [ 68,  81,  97],
#         [ 69,  81, 100],
#         [ 69,  81, 100]],
#
#        [[120, 132, 142],
#         [110, 122, 132],
#         [ 97, 109, 119],
#         ...,
#         [ 78,  91, 107],
#         [ 79,  91, 110],
#         [ 80,  92, 111]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 705.0, 'y': 862.0, 'width': 386.0, 'height': 432.0, 'confidence': 0.5946733355522156, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[120, 132, 144],
#         [121, 133, 145],
#         [123, 135, 147],
#         ...,
#         [ 99, 109, 126],
#         [ 95, 108, 124],
#         [ 97, 110, 126]],
#
#        [[115, 127, 139],
#         [118, 130, 142],
#         [120, 132, 144],
#         ...,
#         [ 95, 105, 122],
#         [ 93, 106, 122],
#         [ 94, 107, 123]],
#
#        [[111, 123, 135],
#         [116, 128, 140],
#         [117, 129, 141],
#         ...,
#         [ 92, 102, 119],
#         [ 92, 105, 121],
#         [ 93, 106, 122]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 708.0, 'y': 865.0, 'width': 380.0, 'height': 424.0, 'confidence': 0.6077015399932861, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[ 95, 110, 121],
#         [102, 117, 128],
#         [112, 127, 138],
#         ...,
#         [104, 114, 131],
#         [103, 113, 130],
#         [103, 113, 130]],
#
#        [[ 62,  77,  88],
#         [ 70,  85,  96],
#         [ 85, 100, 111],
#         ...,
#         [ 96, 106, 123],
#         [ 95, 105, 122],
#         [ 95, 105, 122]],
#
#        [[ 31,  46,  57],
#         [ 41,  56,  67],
#         [ 59,  74,  85],
#         ...,
#         [ 87,  97, 114],
#         [ 86,  96, 113],
#         [ 85,  95, 112]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 708.0, 'y': 866.0, 'width': 382.0, 'height': 422.0, 'confidence': 0.6292667388916016, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[ 86, 101, 112],
#         [ 85, 100, 111],
#         [ 88, 103, 114],
#         ...,
#         [108, 118, 135],
#         [108, 118, 135],
#         [107, 117, 134]],
#
#        [[ 57,  72,  83],
#         [ 55,  70,  81],
#         [ 58,  73,  84],
#         ...,
#         [106, 116, 133],
#         [104, 114, 131],
#         [103, 113, 130]],
#
#        [[ 36,  51,  62],
#         [ 33,  48,  59],
#         [ 35,  50,  61],
#         ...,
#         [101, 111, 128],
#         [100, 110, 127],
#         [ 97, 107, 124]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 710.0, 'y': 883.0, 'width': 400.0, 'height': 392.0, 'confidence': 0.5428758263587952, 'class': 'pas chute', 'image_path': array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [220, 220, 220],
#         [220, 220, 220],
#         [220, 220, 220]],
#
#        [[220, 220, 220],
#         [220, 220, 220],
#         [221, 221, 221],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        ...,
#
#        [[119, 134, 145],
#         [109, 124, 135],
#         [ 92, 107, 118],
#         ...,
#         [113, 124, 139],
#         [115, 126, 141],
#         [117, 128, 143]],
#
#        [[ 95, 110, 121],
#         [ 86, 101, 112],
#         [ 69,  84,  95],
#         ...,
#         [108, 119, 134],
#         [113, 124, 139],
#         [115, 126, 141]],
#
#        [[ 88, 103, 114],
#         [ 78,  93, 104],
#         [ 59,  74,  85],
#         ...,
#         [107, 118, 133],
#         [111, 122, 137],
# ...
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[119, 133, 147],
#         [118, 132, 146],
#         [115, 129, 143],
#         ...,
#         [132, 122, 158],
#         [129, 118, 159],
#         [128, 117, 158]],
#
#        [[119, 133, 147],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [130, 119, 160],
#         [128, 115, 161],
#         [127, 114, 160]],
#
#        [[108, 122, 136],
#         [107, 121, 135],
#         [108, 122, 136],
#         ...,
#         [129, 118, 159],
#         [128, 115, 161],
#         [127, 114, 160]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 675.5, 'y': 562.5, 'width': 241.0, 'height': 127.0, 'confidence': 0.8942143321037292, 'class': 'fire', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[119, 133, 147],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[118, 132, 146],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[108, 122, 136],
#         [108, 122, 136],
#         [112, 126, 140],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [109, 125, 152]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 890.0, 'y': 582.5, 'width': 30.0, 'height': 19.0, 'confidence': 0.7516356706619263, 'class': 'fire', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[119, 133, 147],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[118, 132, 146],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[108, 122, 136],
#         [108, 122, 136],
#         [112, 126, 140],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [109, 125, 152]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 908.0, 'y': 306.0, 'width': 344.0, 'height': 398.0, 'confidence': 0.5540259480476379, 'class': 'smoke', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[119, 133, 147],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[118, 132, 146],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[108, 122, 136],
#         [108, 122, 136],
#         [112, 126, 140],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [109, 125, 152]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 676.5, 'y': 559.0, 'width': 243.0, 'height': 136.0, 'confidence': 0.8978282809257507, 'class': 'fire', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[118, 132, 146],
#         [115, 129, 143],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [110, 126, 153],
#         [112, 128, 155]],
#
#        [[116, 130, 144],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [110, 126, 153],
#         [112, 128, 155]],
#
#        [[107, 121, 135],
#         [108, 122, 136],
#         [114, 128, 142],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [109, 125, 152]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 890.5, 'y': 583.0, 'width': 33.0, 'height': 20.0, 'confidence': 0.7363336086273193, 'class': 'fire', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[118, 132, 146],
#         [115, 129, 143],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [110, 126, 153],
#         [112, 128, 155]],
#
#        [[116, 130, 144],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [110, 126, 153],
#         [112, 128, 155]],
#
#        [[107, 121, 135],
#         [108, 122, 136],
#         [114, 128, 142],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [109, 125, 152]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 909.0, 'y': 308.0, 'width': 342.0, 'height': 400.0, 'confidence': 0.5119599103927612, 'class': 'smoke', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[118, 132, 146],
#         [115, 129, 143],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [110, 126, 153],
#         [112, 128, 155]],
#
#        [[116, 130, 144],
#         [116, 130, 144],
#         [116, 130, 144],
#         ...,
#         [111, 124, 152],
#         [110, 126, 153],
#         [112, 128, 155]],
#
#        [[107, 121, 135],
#         [108, 122, 136],
#         [114, 128, 142],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [109, 125, 152]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 670.0, 'y': 561.5, 'width': 230.0, 'height': 127.0, 'confidence': 0.8874847292900085, 'class': 'fire', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[116, 130, 144],
#         [115, 129, 143],
#         [119, 133, 147],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[116, 130, 144],
#         [116, 130, 144],
#         [120, 134, 148],
#         ...,
#         [110, 123, 151],
#         [108, 124, 151],
#         [110, 126, 153]],
#
#        [[108, 122, 136],
#         [112, 126, 140],
#         [119, 133, 147],
#         ...,
#         [111, 124, 152],
#         [107, 123, 150],
#         [107, 123, 150]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 890.0, 'y': 582.5, 'width': 32.0, 'height': 19.0, 'confidence': 0.7402434945106506, 'class': 'fire', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[116, 130, 144],
#         [115, 129, 143],
#         [119, 133, 147],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[116, 130, 144],
#         [116, 130, 144],
#         [120, 134, 148],
#         ...,
#         [110, 123, 151],
#         [108, 124, 151],
#         [110, 126, 153]],
#
#        [[108, 122, 136],
#         [112, 126, 140],
#         [119, 133, 147],
#         ...,
#         [111, 124, 152],
#         [107, 123, 150],
#         [107, 123, 150]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 907.5, 'y': 303.0, 'width': 345.0, 'height': 386.0, 'confidence': 0.452507346868515, 'class': 'smoke', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[116, 130, 144],
#         [115, 129, 143],
#         [119, 133, 147],
#         ...,
#         [111, 124, 152],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[116, 130, 144],
#         [116, 130, 144],
#         [120, 134, 148],
#         ...,
#         [110, 123, 151],
#         [108, 124, 151],
#         [110, 126, 153]],
#
#        [[108, 122, 136],
#         [112, 126, 140],
#         [119, 133, 147],
#         ...,
#         [111, 124, 152],
#         [107, 123, 150],
#         [107, 123, 150]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [{'x': 673.0, 'y': 567.5, 'width': 234.0, 'height': 113.0, 'confidence': 0.8750610947608948, 'class': 'fire', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[114, 128, 142],
#         [115, 129, 143],
#         [121, 135, 149],
#         ...,
#         [111, 124, 152],
#         [110, 126, 153],
#         [112, 128, 155]],
#
#        [[116, 130, 144],
#         [115, 129, 143],
#         [122, 136, 150],
#         ...,
#         [110, 123, 151],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[109, 123, 137],
#         [114, 128, 142],
#         [123, 137, 151],
#         ...,
#         [110, 123, 151],
#         [107, 123, 150],
#         [107, 123, 150]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}, {'x': 890.0, 'y': 583.0, 'width': 32.0, 'height': 18.0, 'confidence': 0.736504077911377, 'class': 'fire', 'image_path': array([[[217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[225, 228, 228],
#         [225, 228, 228],
#         [226, 229, 229],
#         ...,
#         [222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222]],
#
#        [[240, 243, 243],
#         [240, 243, 243],
#         [241, 244, 244],
#         ...,
#         [241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241]],
#
#        ...,
#
#        [[114, 128, 142],
#         [115, 129, 143],
#         [121, 135, 149],
#         ...,
#         [111, 124, 152],
#         [110, 126, 153],
#         [112, 128, 155]],
#
#        [[116, 130, 144],
#         [115, 129, 143],
#         [122, 136, 150],
#         ...,
#         [110, 123, 151],
#         [109, 125, 152],
#         [110, 126, 153]],
#
#        [[109, 123, 137],
#         [114, 128, 142],
#         [123, 137, 151],
#         ...,
#         [110, 123, 151],
#         [107, 123, 150],
#         [107, 123, 150]]], dtype=uint8), 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': 1080, 'height': 1080}}
# {'predictions': [], 'image': {'width': 1080, 'height': 1080}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\dioud\Desktop\projet8v\test.ipynb Cell 1 in <cell line: 82>()
#      <a href='vscode-notebook-cell:/c%3A/Users/dioud/Desktop/projet8v/test.ipynb#W0sZmlsZQ%3D%3D?line=81'>82</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/dioud/Desktop/projet8v/test.ipynb#W0sZmlsZQ%3D%3D?line=84'>85</a>     ret,image=cap.read()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/dioud/Desktop/projet8v/test.ipynb#W0sZmlsZQ%3D%3D?line=85'>86</a>     print(model.predict(image, confidence=40, overlap=30).json())
#      <a href='vscode-notebook-cell:/c%3A/Users/dioud/Desktop/projet8v/test.ipynb#W0sZmlsZQ%3D%3D?line=86'>87</a>     predictions=model.predict(image, confidence=40, overlap=30).json()
#      <a href='vscode-notebook-cell:/c%3A/Users/dioud/Desktop/projet8v/test.ipynb#W0sZmlsZQ%3D%3D?line=87'>88</a>     predictions1=model1.predict(image, confidence=40, overlap=30).json()
#
# File c:\Users\dioud\anaconda3\envs\simulation-IA\lib\site-packages\roboflow\models\object_detection.py:145, in ObjectDetectionModel.predict(self, image_path, hosted, format, classes, overlap, confidence, stroke, labels)
#     143 # If image is local image
#     144 if not hosted:
# --> 145     if ".jpg" in image_path or ".png" in image_path:  # Open Image in RGB Format
#     146         image = Image.open(image_path).convert("RGB")
#     148         # Create buffer
#
# TypeError: argument of type 'NoneType' is not iterable
